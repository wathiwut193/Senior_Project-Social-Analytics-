# %%
from pythainlp.spell.pn import *
import time

# %%
start = time.time()
read_text = open('print.txt','r',encoding='utf-8')
text = read_text.read()
x = text.split("|")

#print(x[0])
for i in x:
    print(correction(i))
read_text.close()

end = time.time()
print(end-start)
# Out:
# กองทัพ
# ไม่
# อิก
# ซื้อ
# จีที
# หน่วย
# ยัน
# ใช้
# ได้
# เผย
# ฟ้อง
# บริษัท
# ตัว
# แทน
# เเล้ว
# ชี้
# ทุกอย่าง
# อยู่
# ใน
# กระบวนการ
# ครุย
# ยะ
# ยะ
# 0.26702356338500977

# %%
start = time.time()
read_text = open('politics_output.txt','r',encoding='utf-8')
text = read_text.read()
x = text.split("|")

#print(x[0])
for i in x:
    print(correction(i))
read_text.close()

end = time.time()
print(end-start)
# Out:
# ปลื้ม
# เตรียม
# ร่วม
# ประชาธิปัตย์
# เผย
# พ่อ
# สนับสนุน
# สุรบถหลีก
# ภัย
# เตรียม
# สมัคร
# สมาชิก
# พรรคประชาธิปัตย์
# เผย
# พร้อม
# ลง
# ส.ส.
# แบบ
# แบ่ง
# เขต
# ยะ
# ปาร์ตี้ลิสต์
# 2.17099666595459

# %% [markdown]
# # ยังแก้ตัวเลขเป็นคำอยู่

# %% [markdown]
# # news1 แก้ ดังวกล่าว เป็น ดังกล่าว ได้

# %%
start = time.time()
read_text = open('คลังข่าว/news_1_ตัด.txt','r+',encoding='utf-8')
text = read_text.read()
x = text.split("|")

#print(x[0])
for i in x:
    if i != " " and i != '' and i != "\n":
            print(correction(i))
        
read_text.close()

end = time.time()
print(end-start)
# Out:
# จับ
# ไฝ
# หนุ่ม
# โชว์
# ปืน
# ขู่
# เด็ก
# ปั๊ม
# แถม
# ดูด
# กัญชา
# โดน
# ไป
# ฤณ
# ข้อ
# หา
# โดย
# ไทย
# รัฐ
# ออนไลน์
# ไฝ
# ม.ค.
# 2562
# แซ
# ฤณ
# ยอ
# น.
# Share
# ฤณ
# สอง
# หนุ่ม
# คู่หู
# มี
# ปืน
# อยู่
# ฤณ
# กระบอก
# โชว์
# ขู่
# เด็ก
# ปั๊ม
# ก่อน
# ไป
# ทำ
# แบบ
# เดียว
# กัน
# กับ
# โจ๋
# ที่
# จับ
# กลุ่ม
# กัน
# อยู่
# โดน
# 191
# ตาม
# จับ
# สารภาพ
# เพิ่ง
# ดูด
# กัญชา
# มา
# เลย
# โดน
# จับกัญชา
# พ่วง
# ไป
# ด้วย
# เมื่อ
# เวลา
# แซ
# ฟ.
# บอ
# น.
# วัน
# ที่
# ไฝ
# ม.ค.
# ที่
# ห้อง
# ปฏิบัติการ
# งาน
# สาย
# ตรวจ
# ทบ
# หอบังคับการ
# สาย
# ตรวจ
# และ
# ปฏิบัติการ
# พิเศษ
# 191
# ฤณ
# บก.สปพ.
# ฤณ
# ถนนวิภาวดี
# พล.ต.ต.สำราญ นวลมา
# ผบก.สปพ.
# พร้อม
# ด้วย
# พ.ต.อ.สมบูรณ์ เทียนขาว
# ผกก.
# สาย
# ตรวจ
# บก.สปพ.
# พ.ต.ท.อานันท์จักร์ กนกนพวัชร์
# รอง
# ผกก.
# สาย
# ตรวจ
# ร่วม
# กัน
# แถลง
# ผล
# การ
# จับกุม
# นายแบ้ง ทองแท้
# อายุ
# ไฝ
# ปี
# ชาว
# จ.
# ปราจีนบุรี
# และ
# นายกฤษฎา โป๊ะแก้ว
# อายุ
# ไฝ
# ปี
# ชาว
# ชลบุรี
# โดย
# สามารถ
# จับกุม
# ได้
# ...

# %% [markdown]
# # news2 ผิดคำว่า 'เขวดเหล้า' แก้คำว่า 'ขวด' ได้ แต่ 'เหล้า' แก้เป็น 'หล้า'
# # คำว่า 'กางขายาว' จริงๆต้องเป็น กางเกงขายาว แต่ มันแก้เป็น กังขา

# %%
start = time.time()
read_text = open('news/news_2_ตัด.txt','r+',encoding='utf-8')
text = read_text.read()
x = text.split("|")


#print(x[0])
for i in x:
    if i != " " and i != '' and i != "\n":   
        print(correction(i))
        
read_text.close()

end = time.time()
print(end-start)
# Out:
# ไม้
# หน้า
# สาม
# ฟาดหัว
# กิ๊ก
# สาว
# ดับ
# เฒ่า
# วัย
# พอ
# หนี
# ผิด
# ซด
# ยา
# ฆ่า
# แมลง
# แขวน
# สยอง
# โดย
# ไทย
# รัฐ
# ออนไลน์
# กฎ
# ม.ค.
# 2562
# จญ
# ยะ
# กฎ
# น.
# ฆ่า
# กิ๊ก
# สาว
# วัย
# กฎ
# ไม้
# หน้า
# สาม
# ฟาด
# หัวสูง
# ที่
# เชียงใหม่
# เฒ่า
# วัย
# พอ
# กลัว
# ความ
# ผิด
# ซด
# เหล้า
# ผสม
# ยา
# ฆ่า
# แมลง
# ก่อน
# แขวน
# คอ
# ตาย
# ตาม
# ใน
# ห้อง
# นอน
# ตร.
# คาด
# มีชู้
# สาว
# เชื่อ
# มี
# การ
# นัดแนะ
# ให้
# มา
# พบ
# กัน
# และ
# เกิด
# มี
# ปากเสีย
# มง
# มช.
# เมื่อ
# เวลา
# กฎ
# อ.
# จญ
# น.
# วัน
# ที่
# ฟี
# ม.ค.
# คง
# ร.ต.อ.ทินกร โชติชัยพิบูล
# รอง
# สวย
# ยะ
# สอบสวน
# ยะ
# สภ.สันกำแพง
# เชียงใหม่
# ได้
# รับ
# แจ้ง
# มี
# เหตุ
# ฆ่า
# กัน
# และ
# แขวน
# คอ
# ตาย
# ที่
# ห้อง
# แถว
# หมู่
# บ้านแพวาสัน
# ป่าช้า
# เลข
# ที่
# 147
# ยะ
# กำ
# หมู่
# ยะ
# ต.ต้นเปา
# อ.สันกำแพง
# จึง
# รุด
# ไป
# ตรวจสอบ
# ที่
# เกิด
# เหตุ
# พร้อม
# ด้วย
# พ.ต.อ.ชูวิทย์ กองแก้ว
# ผกก.
# พ.ต.ท.ถาวร นันติแสน
# รอง
# ผกก.
# ยะ
# สอบสวน
# ยะ
# ...

# %% [markdown]
# # news3 แก้คำว่า 'ได่' เป็น 'ไป่' แล้วก็คำว่า โปรแกรมเมอร์ ตัดแยกเป็น โปรแกรม|เมอร์ เลยแก้คำว่า 'เมอร์' เป็น 'เซอร์'

# %%
start = time.time()
read_text = open('news/news_3_ตัด.txt','r+',encoding='utf-8')
text = read_text.read()
x = text.split("|")

#print(x[0])
for i in x:
    if i != " " and i != '' and i != "\n":
            print(correction(i))
        
read_text.close()

end = time.time()
print(end-start)
# Out:
# รู้
# ตัว
# คน
# ร้าย
# ฆ่า
# หั่น
# ศพ
# หนุ่ม
# เกาหลีใต้
# พบ
# เป็น
# คน
# ร่วม
# ชาติ
# ขัดแย้ง
# ธุรกิจ
# มืด
# โดย
# ไทย
# รัฐ
# ออนไลน์
# กฎ
# ม.ค.
# 2562
# กค
# ยะ
# พง
# น.
# หนุ่ม
# โปรแกรม
# เมอร์วัย
# คง
# ปี
# พร้อม
# เจ้าหน้าที่
# สถาน
# ทูต
# เกาหลีใต้
# มา
# มอบ
# ตัว
# ถึง
# กองปราบ
# หลัง
# ร่วม
# อยู่
# ใน
# เหตุการณ์
# เพื่อน
# ร่วม
# ชาติ
# ถูก
# ฆ่า
# หั่น
# ศพ
# นำ
# ชิ้นส่วน
# ทิ้ง
# ป่า
# ใน
# ระยอง
# เผย
# ถูก
# บังคับ
# ให้
# นั่ง
# ดู
# ถ้า
# ไม่
# ดู
# จะ
# กลาย
# เป็น
# ศพ
# แทน
# จาก
# กรณี
# ที่
# มี
# ชาว
# บ้าน
# พบ
# ชิ้นส่วน
# มนุษย์
# ที่
# นำ
# มา
# ทิ้ง
# ไว้
# บริเวณ
# ป่า
# ส่วนแบ่ง
# ชาติหนองสนม
# จังหวัดระยอง
# โดย
# ชิ้นส่วน
# ดัง
# กล่าว
# น่า
# จะ
# เป็น
# นายชเว มยองฮุน ชื่อ
# ยะ
# CHOI
# MYONGHOON
# ยะ
# อายุ
# ดก
# ปี
# ชาว
# เกาหลีใต้
# ตาม
# ที่
# ไป่
# เสนอ
# ข่าว
# ไป
# ก่อนหน้า
# นี้
# ยะ
# รู้
# แล้ว
# ฆ่า
# หั่น
# ศพ
# ยัด
# ถุง
# ดำ
# ทิ้ง
# ระยอง
# เป็น
# หนุ่ม
# เกาหลีใต้
# ยะ
# ล่าสุด
# เมื่อ
# เวลา
# จญ
# อ.
# พง
# น.
# ...

# %% [markdown]
# # news 4 แก้ 'ๆ' เป็นคำอื่น และ ชื่อนามสกุลบุคคล คือ 'พ.ต.ท.ภูมิทัศ ปิติจิระนน' แต่ตัดเป็น พ.ต.ท.ภูมิทัศ ปิติ|จิระนน มันเลยไปแก้ 'จิระนน' เป็น 'จระนำ'

# %%
start = time.time()
read_text = open('news/news_4_ตัด.txt','r+',encoding='utf-8')
text = read_text.read()
x = text.split("|")

#print(x[0])
for i in x:
    if i != " " and i != '' and i != "\n":
            print(correction(i))
        
read_text.close()

end = time.time()
print(end-start)
# Out:
# จับ
# ลูก
# ชาย
# วนิษฐา วัชโรบล ดารา
# รุ่น
# ใหญ่
# ยิง
# อริ
# จับ
# บั้นท้าย
# เพื่อน
# สาว
# ใน
# ผับ
# โดย
# ไทย
# รัฐ
# ออนไลน์
# กฎ
# ม.ค.
# 2562
# กค
# ยะ
# ดก
# น.
# กองปราบ
# จับ
# ลูก
# ชาย
# วนิษฐา วัชโรบล ดารา
# รุ่น
# ใหญ่
# ละคร
# จักร
# ยะ
# วงศ์
# ยะ
# ตาม
# หมาย
# หลัง
# ร่วม
# ยิง
# อริ
# ที่
# จับ
# บั้นท้าย
# เพื่อน
# สาว
# ใน
# ผับ
# ที่
# ปาก
# ช่อง
# เจ้าตัว
# ปฏิเสธ
# รับ
# มี
# เรื่อง
# จริง
# แต่
# ออก
# จาก
# ผับ
# ก็
# แยกย้าย
# มช.
# วัน
# ที่
# กฎ
# ม.ค.
# คง
# ที่
# หอบังคับการ
# ปราบปราม
# พล.ต.ต.จิรภพ ภูริเดช
# ผบก.ทล.
# สั่งการ
# ให้
# พ.ต.อ.บุญลือ ผดุงถิ่น
# ผกก.
# ยะ
# บกท.
# พ.ต.ท.สุริยศักดิ์ จิราวัสน์
# สวย
# กก.
# บกท.
# พ.ต.ท.ภูมิทัศ ปิติ
# จระนำ
# สวย
# กก.
# บกท.
# นำ
# กำลัง
# จับกุม
# นายณัฎฐชัย บุญญาหาร
# อายุ
# พง
# ปี
# ลูก
# ชาย
# ของ
# นางวนิษฐา วัชโรบล
# นัก
# แสดง
# ละคร
# จักรๆ วงศ์
# ยะ
# รุ่น
# ใหญ่
# ตาม
# หมาย
# จับ
# ศาล
# สี
# คิ้ว
# ที่
# ชด
# ยะ
# 2555
# ฐาน
# ความ
# ผิด
# ยะ
# ร่วม
# กัน
# ฆ่า
# ผู้
# อื่น
# โดย
# เจตนา
# ...

# %% [markdown]
# # news5 แก้คำว่า 'จาการ' เป็น 'อาการ'

# %%
start = time.time()
read_text = open('news/news_5_ตัด.txt','r+',encoding='utf-8')
text = read_text.read()
x = text.split("|")

#print(x[0])
for i in x:
    if i != " " and i != '' and i != "\n":
            print(correction(i))
        
read_text.close()

end = time.time()
print(end-start)
# Out:
# ที่
# แท้
# สิบ
# เอกควบเก๋ง
# ชน
# คู่
# กรณี
# ยะ
# จงใจ
# ฆ่า
# ตัว
# ตาย
# ยะ
# หลัง
# แทง
# เมีย
# ดับ
# สยอง
# โดย
# ไทย
# รัฐ
# ออนไลน์
# กฎ
# ม.ค.
# 2562
# จญ
# ยะ
# กค
# น.
# ที่
# แท้
# ยะ
# สิบ
# เอก
# ยะ
# ขับ
# เก๋ง
# โตโยต้า
# พุ่ง
# ชน
# กระบะ
# คู่
# กรณี
# ขณะ
# จอด
# รอ
# กลับ
# รถ
# หน้า
# ห้าง
# ดัง
# เมืองภูเก็ต
# จน
# ตัว
# เอง
# เสียชีวิต
# ยะ
# จงใจ
# ฆ่า
# ตัว
# ตาย
# ยะ
# หลัง
# เพิ่ง
# ก่อ
# เหตุ
# จ้วง
# แทง
# อดีต
# ภรรยา
# เสียชีวิต
# สยอง
# คา
# บ้าน
# มช.
# จาก
# กรณี
# เมื่อ
# เวลา
# กค
# อ.
# จญ
# น.
# วัน
# ที่
# ดก
# ม.ค.
# คง
# เกิด
# อุบัติเหตุ
# รถยนต์
# ชน
# กัน
# บน
# ถนนเฉลิมพระเกียรติ
# ร.
# ยะ
# บายพาส
# ยะ
# จุด
# กลับ
# รถ
# หน้า
# ห้าง
# เอาต์เล็ตภูเก็ต
# ม.
# ยะ
# รัษฎา
# เมือง
# เป็น
# เหตุ
# ให้
# ส.อ.ภานุรุจ เพ็ชร์ช่วย
# อายุ
# กษ
# ปี
# บ้าน
# อยู่
# เมือง
# นครศรีธรรมราช
# เสียชีวิต
# ใน
# ที่
# เกิด
# เหตุ
# ส่วน
# คู่
# กรณี
# คือ
# นายสถิตย์ วงษา
# อายุ
# ดก
# ปี
# ได้
# รับ
# บาดเจ็บ
# เจ้าหน้าที่
# นำ
# ตัว
# ส่ง
# รพ.
# ...

# %% [markdown]
# # news6 คำว่า 'เมียหลวงพ่อ' ถูกตัดเป็น เมีย|หลวงพ่อ แต่จริงๆต้องเป็น เมียหลวง|พ่อ และคำว่า 'เหวอะชวนสยอง' ถูกตัดเป็น 'เหว|อะชวน|สยอง' แต่จริงๆต้อง 'เหวอะ|ชวน|สยอง'

# %%
start = time.time()
read_text = open('news/news_6_ตัด.txt','r+',encoding='utf-8')
text = read_text.read()
x = text.split("|")

#print(x[0])
for i in x:
    if i != " " and i != '' and i != "\n":
        print(correction(i))
        
read_text.close()

end = time.time()
print(end-start)
# Out:
# ปลูก
# เมีย
# น้อย
# เก็บกด
# ฆ่า
# เมีย
# หลวงพ่อ
# กับ
# น้อง
# ต่าง
# แม่
# ชัก
# มีด
# จ้วง
# แทง
# ระบายแค้น
# โดย
# ไทย
# รัฐฉบับ
# พิมพ์
# กฎ
# ม.ค.
# 2562
# จญ
# ยะ
# ดก
# น.
# กบดาน
# บ้าน
# เช่า
# ก่อน
# จน
# มุม
# อ้าง
# ว่า
# ทั้ง
# คู่
# ชอบ
# พูด
# ถาก
# ถาง
# ลูก
# เมีย
# น้อย
# บุก
# ฆ่า
# โหด
# เมีย
# หลวง
# ของ
# พ่อ
# กับ
# ลูก
# ชาย
# ดับ
# สยอง
# ยะ
# ศพ
# วางแผน
# ขี่
# จยย.
# มา
# ดัก
# รอ
# เหยื่อ
# ราย
# แรก
# ที่
# เป็น
# ลูก
# ชาย
# เมีย
# หลวง
# ล้างรถ
# จยย.
# เสีย
# เรียก
# ให้
# ช่วย
# ดู
# จังหวะ
# เผลอ
# กลับ
# ใช้
# มีด
# จ้วง
# แทง
# ไม่
# ยั้ง
# ก่อน
# เชือด
# คอ
# ซ้ำ
# จาก
# นั้น
# ตาม
# ไป
# กะ
# ซึก
# เมีย
# หลวง
# ของ
# พ่อ
# ขณะ
# นั่ง
# เก้าอี้
# โยก
# ดู
# ทีวี
# เลือด
# สาด
# กระเซ็น
# ขณะ
# ที่
# พ่อ
# เห็น
# พอดี
# รีบ
# วิ่ง
# หนี
# ตาม
# ล็อก
# ตัว
# ไว้
# แต่
# สะบัด
# หลบหนี
# ไป
# แต่
# ไม่
# รอด
# ถูก
# ตำรวจ
# ตาม
# รวบ
# ตัว
# ไว้
# ได้
# สารภาพ
# ถูก
# เหยื่อ
# ต่อว่า
# สาร
# พัด
# เลย
# เก็บ
# ขัดแค้น
# ฝังใจ
# ลูก
# เมีย
# ...

# %% [markdown]
# # news 7 คำว่า 'หัส' ต้องเป็น 'สาหัส' แต่มันไม่แก้

# %%
start = time.time()
read_text = open('news/news_7_ตัด.txt','r+',encoding='utf-8')
text = read_text.read()
x = text.split("|")

#print(x[0])
for i in x:
    if i != " " and i != '' and i != "\n":
            print(correction(i))
        
read_text.close()

end = time.time()
print(end-start)
# Out:
# พ่อค้า
# ตลาด
# นัดเมืองเพชร
# โหด
# สั่ง
# ตาย
# ไล่
# ยิง
# คู่
# อริ
# พ่อแม่
# ลูก
# ดับ
# ยะ
# สาหัส
# ยะ
# ยะ
# คลิป
# ยะ
# โดย
# ไทย
# รัฐ
# ออนไลน์
# กฎ
# ม.ค.
# 2562
# จญ
# ยะ
# กำ
# น.
# พ่อค้า
# ตลาด
# ขัดขืน
# โหด
# ยิง
# กระหน่ำ
# พ่อค้า
# คู่
# อริ
# ตาย
# วางตลาด
# ไม่
# หนำใจ
# เดิน
# ไป
# ยิง
# แม่
# คู่
# อริ
# ให้
# ตาย
# ตาม
# ลูก
# อีก
# ยะ
# แถม
# ยิง
# พ่อ
# คน
# ตาย
# อาการ
# บาดเจ็บ
# สาหัส
# ก่อน
# หลบหนี
# ตร.
# เขา
# ย้อยเร่ง
# ล่า
# ตัว
# มช.
# เมื่อ
# เวลา
# จญ
# อ.
# พง
# น.
# วัน
# ที่
# กฎ
# มกราคม
# ร.ต.ท.ยศพล พันธุ
# ร้อย
# เวร
# สภ.เขาย้อย
# เพชรบุรี
# รับ
# แจ้ง
# มี
# เหตุ
# คน
# ถูก
# ยิง
# ภาย
# ใน
# ตลาด
# นัดหนองปรง
# หมู่
# ยะ
# ต.หนองปรง
# อ.เขาย้อย
# เพชรบุรี
# มี
# ผู้
# ได้
# รับ
# บาดเจ็บ
# และ
# เสียชีวิต
# จึง
# รายงาน
# ไป
# ยัง
# พ.ต.อ.สมเดช ฐิตวัฒนะสกุล
# รอง
# ผจก.
# ภ.จว.เพชรบุรี
# พ.ต.อ.สมเกียรติ โฉมฉาย
# ผกก.
# สภ.เขาย้อย
# ทราบ
# พร้อม
# ประสาน
# แพทย์
# เวร
# รพ.เขาย้อย
# เจ้าหน้าที่
# ตำรวจ
# พิสูจน์
# หลักฐาน
# ...

# %% [markdown]
# # news8 ไม่มีคำว่า 'หวง' เลยแก้เป็น 'เหวง' และคำว่า 'คุดสวน' แก้เป็น 'สุดสงวน'

# %%
start = time.time()
read_text = open('news/news_8_ตัด.txt','r+',encoding='utf-8')
text = read_text.read()
x = text.split("|")

#print(x[0])
for i in x:
    if i != " " and i != '' and i != "\n":
        print(correction(i))
        
read_text.close()

end = time.time()
print(end-start)
# Out:
# เหวง
# มัง
# สุดสงวน
# เพื่อน
# ถือ
# พร้า
# หาเรื่อง
# เด็ก
# เลี้ยง
# วัว
# ยิง
# ดับ
# คา
# คอก
# โดย
# ไทย
# รัฐ
# ออนไลน์
# ดก
# ม.ค.
# 2562
# กฎ
# ยะ
# จญ
# น.
# มังคุด
# ตาย
# หนุ่ม
# เมืองร้อน
# หวง
# กว้างขวาง
# ไม่
# ให้
# ใคร
# ไป
# เหมา
# สวน
# เก็บ
# มัง
# คุด
# ของ
# เพื่อนบ้าน
# ถือ
# มีดพร้า
# ไป
# หา
# เรื่อง
# ไล่
# ฟัน
# หนุ่ม
# เลี้ยง
# วัวนม
# คอก
# ส.ต.
# ดัง
# โดน
# ยิง
# สวน
# ยะ
# นัด
# ดับ
# คา
# ที่
# เวลา
# กค
# อ.
# พง
# น.
# วัน
# ที่
# ดก
# ม.ค.
# ร.ต.อ.วัชรินทร์ คงเพ็ชร
# รอง
# สวย
# ยะ
# สอบสวน
# ยะ
# สภ.เมืองนครศรีธรรมราช
# ได้
# รับ
# แจ้ง
# ว่า
# มี
# เหตุ
# ยิง
# กัน
# ตาย
# ที่
# บริเวณ
# ข้าง
# คอก
# เลี้ยง
# วัวนม
# ไม่
# มี
# เลข
# ที่
# หมู่
# ยะ
# ต.โพธิ์เสด็จ
# อ.เมืองนครศรีธรรมราช
# ซึ่ง
# ที่
# เกิด
# เหตุ
# เป็น
# คอก
# เลี้ยง
# วัว
# ชน
# ชื่อ
# ดัง
# ของ
# ส.จ.แอ๋ว
# หรือ
# นายสมชาย
#  เกตุชาติ
# ส.อบจ.นครศรีธรรมราช
# เขต
# เมือง
# ที่
# เกิด
# เหตุ
# บริเวณ
# พื้น
# ดิน
# ข้าง
# คอก
# เลี้ยง
# วัวนม
# พบ
# ศพ
# ผู้
# ตาย
# ชื่อ
# ...

# %% [markdown]
# # news9 คำว่า 'เสียตาย' แก้เป็น 'เสียหาย' ได้ และคำว่า 'เตาย' แก้เป็น 'ตาย' แต่คำว่า 'พระปลอม' ซึ่งน่าจะไม่มีใน Dict เลยถูกแก้เป็น 'พระน้อม'

# %%
start = time.time()
read_text = open('news/news_9_ตัด.txt','r+',encoding='utf-8')
text = read_text.read()
x = text.split("|")

#print(x[0])
for i in x:
    if i != " " and i != '' and i != "\n":
        print(correction(i))
        
read_text.close()

end = time.time()
print(end-start)
# Out:
# ﻿พระจริง
# ฆ่า
# พระน้อม
# ร่วม
# ร่ำสุรา
# ยะ
# ทวง
# เงิน
# แทง
# ดับ
# คา
# เต็นท์
# ที่พัก
# โดย
# ไทย
# รัฐ
# ออนไลน์
# ดก
# ม.ค.
# 2562
# กค
# ยะ
# กฎ
# น.
# จับ
# แล้ว
# ฆาตกร
# ฆ่า
# พระทอง
# ดับ
# คา
# เต็นท์
# ที่
# พำนักย่าน
# ทวีวัฒนา
# เป็น
# เพื่อน
# พระ
# ร่วม
# ร่ำสุรา
# ก่อน
# ทวง
# เงิน
# แล้ว
# ฆ่า
# กัน
# ตาย
# สารภาพ
# ตัว
# เอง
# เป็น
# ระเริง
# ส่วน
# ผู้
# ตาย
# เป็น
# พระน้อม
# ห่ม
# จีวร
# ออก
# บิณฑบาต
# วัน
# ที่
# ดก
# ม.ค.
# เจ้าหน้าที่
# ตำรวจ
# ควบคุม
# ตัว
# นายประสงค์ ราญรอน
# ชาว
# จันทบุรี
# อายุ
# กำ
# ปี
# อดีต
# พระภิกษุ
# ทำ
# แผน
# ประกอบ
# รับ
# คำ
# สารภาพ
# หลัง
# ก่อ
# เหตุ
# ฆาตกรรม
# ประกล
# หรือ
# นายสกล ภูมี
# อายุ
# ชด
# ปี
# ด้วย
# อาวุธ
# มีด
# บริเวณ
# เพิง
# พัก
# ชั่วคราว
# กลาง
# ป่า
# หญ้า
# ริม
# ถนนพุทธมณฑลสาย 4
# เขตทวีวัฒนา
# กทม.
# เมื่อ
# ช่วง
# เช้า
# วัน
# ที่
# ฟี
# ม.ค.
# ที่
# ผ่าน
# มา
# ขณะ
# กำลัง
# หลบหนี
# ไป
# อยู่
# ใน
# จันทบุรี
# จน
# ถูก
# ตำรวจ
# สืบสวน
# ตาม
# ไป
# จับ
# หลัง
# มี
# พยาน
# ให้การ
# ...

# %% [markdown]
# # news10 คำว่า 'เมียนมา' เมื่อตัดแยก เมียน|มา จะแก้เป็น 'เสมียน|มา' และ คำว่า 'ประสานงาน' เมื่อตัดแยก 'ประสานงา|น' จะแก้เป็น 'ประสานงา|จน'

# %%
start = time.time()
read_text = open('news/news_10_ตัด.txt','r+',encoding='utf-8')
text = read_text.read()
x = text.split("|")

#print(x[0])
for i in x:
    if i != " " and i != '' and i != "\n":
        print(correction(i))
        
read_text.close()

end = time.time()
print(end-start)
# Out:
# ﻿ขานรับนโยบาย
# ยะ
# บิ๊กโจ๊ก
# ยะ
# ตม.
# เชียงราย
# จัด
# ทีม
# ไม่น่า
# ยะ
# เทพโซโล
# ยะ
# โดย
# ไทย
# รัฐ
# ออนไลน์
# ดก
# ม.ค.
# 2562
# จญ
# ยะ
# กำ
# น.
# ตม.
# เชียงราย
# ขานรับนโยบาย
# ยะ
# บิ๊กโจ๊ก
# ยะ
# ร่วม
# ยะ
# บีบีซี
# ยะ
# เจ้าหน้าที่
# ทหาร
# และ
# ตร.
# แม่ยาย
# ประสานงา
# จน
# ไม่น่า
# ยะ
# เทพโซโล
# ยะ
# หัวหน้า
# แก๊ง
# ยาจนก
# มัน
# ทุก
# เม็ด
# ที่
# หนี
# การ
# จับกุม
# ไป
# อยู่
# ประเทศเมียนมา
# กลับ
# มา
# ยัด
# คุกเมืองไทย
# เมื่อ
# วัน
# ที่
# กฎ
# ม.ค.
# คง
# พ.ต.อ.เอกกร บุษบาบดินทร์
# ผกก.
# ตม.เชียงราย
# พร้อม
# เจ้าหน้าที่
# ชุด
# ประสานงา
# จน
# ชาย
# แดน
# ส่วน
# ท้องถิ่น
# ไทย
# ยะ
# เมียนมาร์
# อ่าวไทย
# หรือ
# ยะ
# บีบีซี
# ยะ
# ข้าม
# สะพาน
# ด่านพรมแดน
# ไทย
# ยะ
# เสมียน
# มา
# แห่ง
# ที่จะ
# อ.แม่สาย
# เชียงราย
# เข้า
# พบ
# ตำรวจ
# จ.ท่าขี้เหล็ก
# เป็น
# วัน
# ที่
# ยะ
# เพื่อ
# ติดตาม
# คดี
# นายปัณณวิชญ์
# ประทุน
# ซึ่ง
# ใช้
# เฟซบุ๊ก
# ยะ
# เทพบุตร
# โซโล
# ยะ
# หัวหน้า
# แก๊ง
# ค้ายาเสพติด
# มัน
# ทุก
# เม็ด
# ผู้ต้องหา
# หนี
# หมาย
# ...
